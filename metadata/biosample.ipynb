# %%
import pandas as pd
import biosample

# %%
sra = pd.read_csv('sra.csv')
sra
# Out:
#           biosample          acc assay_type  \
# 0      SAMD00235537    DRR237204    RNA-Seq
# 1      SAMN30889879  SRR21660183    RNA-Seq
# 2      SAMN09513405   SRR7447776    RNA-Seq
# 3      SAMN09078292   SRR7124263    RNA-Seq
# 4      SAMN36760700  SRR25459671    RNA-Seq
# ...             ...          ...        ...
# 10987  SAMN25827181  SRR17968854    RNA-Seq
# 10988  SAMN20971793  SRR15610895    RNA-Seq
# 10989  SAMN41726398  SRR29315715    RNA-Seq
# 10990  SAMN07202264   SRR5655591    RNA-Seq
# 10991  SAMN09716352   SRR7592877    RNA-Seq
#
#                                              center_name consent   experiment  \
# 0                                             RIKEN_CSRS  public    DRX227388
# 1      INNER MONGOLIA ACADEMY OF AGRICULTURAL & ANIMA...  public  SRX17659913
# 2                              THE OHIO STATE UNIVERSITY  public   SRX4318240
# 3                                                    GEO  public   SRX4045331
# 4                                                SOYBEAN  public  SRX21192507
# ...                                                  ...     ...          ...
# 10987                   HUAZHONG AGRICULTURAL UNIVERSITY  public  SRX14125189
# 10988                                                GEO  public  SRX11908208
# 10989                  NORTHEAST AGRICULTURAL UNIVERSITY  public  SRX24832506
# 10990                                                GEO  public   SRX2892180
# 10991                                                GEO  public   SRX4457873
#
#                   sample_name             instrument librarylayout  \
# 0                SAMD00235537    Illumina HiSeq 2500        PAIRED
# 1                CK (1,2,3,4)  Illumina NovaSeq 6000        PAIRED
# 2                    SL209648    Illumina HiSeq 2500        PAIRED
# 3                  GSM3132253    Illumina HiSeq 2000        SINGLE
# 4                     R89-2-1    Illumina HiSeq 4000        PAIRED
# ...                       ...                    ...           ...
# 10987  II-Early-12dpi-2C_rep2    Illumina HiSeq 4000        PAIRED
# 10988              GSM5536784    AB SOLiD System 3.0        PAIRED
# 10989               HPHO_MM_2    Illumina HiSeq 2000        PAIRED
# 10990              GSM2651534    Illumina HiSeq 2500        PAIRED
# 10991              GSM3306085    Illumina HiSeq 4000        SINGLE
#
#       libraryselection  ... geo_loc_name_country_continent_calc  \
# 0                PolyA  ...                                 NaN
# 1                 cDNA  ...                                Asia
# 2                PolyA  ...                       North America
# 3                 cDNA  ...                                 NaN
# 4                  PCR  ...                                Asia
# ...                ...  ...                                 ...
# 10987         Oligo-dT  ...                        uncalculated
# 10988             cDNA  ...                                 NaN
# 10989           RT-PCR  ...                                Asia
# 10990             cDNA  ...                                 NaN
# 10991             cDNA  ...                                 NaN
#
#         geo_loc_name_sam ena_first_public_run ena_last_update_run  \
# 0                    NaN                  NaN                 NaN
# 1        [China: Hohhot]                  NaN                 NaN
# 2            [USA: Ohio]                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4      [China:Changchun]                  NaN                 NaN
# ...                  ...                  ...                 ...
# 10987    [not collected]                  NaN                 NaN
# 10988                NaN                  NaN                 NaN
# 10989     [China:Harbin]                  NaN                 NaN
# 10990                NaN                  NaN                 NaN
# 10991                NaN                  NaN                 NaN
#
#                  sample_name_sam    datastore_filetype datastore_provider  \
# 0      [Aspergillus_oryzae_DAS6]         [sra, run.zq]     [s3, ncbi, gs]
# 1                            NaN  [sra, run.zq, fastq]     [ncbi, gs, s3]
# 2                            NaN  [fastq, run.zq, sra]     [gs, ncbi, s3]
# 3                            NaN  [fastq, run.zq, sra]     [gs, ncbi, s3]
# 4                            NaN  [sra, run.zq, fastq]     [s3, gs, ncbi]
# ...                          ...                   ...                ...
# 10987                        NaN  [run.zq, sra, fastq]     [s3, ncbi, gs]
# 10988                        NaN          [fastq, sra]     [s3, gs, ncbi]
# 10989                        NaN  [sra, run.zq, fastq]     [gs, ncbi, s3]
# 10990                        NaN  [fastq, run.zq, sra]     [gs, ncbi, s3]
# 10991                        NaN         [run.zq, sra]     [gs, ncbi, s3]
#
#                                datastore_region  run_file_version    random
# 0      [ncbi.public, s3.us-east-1, gs.us-east1]               1.0  0.999995
# 1      [ncbi.public, s3.us-east-1, gs.us-east1]               1.0  0.999912
# 2      [gs.us-east1, ncbi.public, s3.us-east-1]               1.0  0.999817
# 3      [gs.us-east1, ncbi.public, s3.us-east-1]               1.0  0.999636
# 4      [ncbi.public, gs.us-east1, s3.us-east-1]               1.0  0.999558
# ...                                         ...               ...       ...
# 10987  [gs.us-east1, ncbi.public, s3.us-east-1]               1.0  0.000529
# 10988  [s3.us-east-1, gs.us-east1, ncbi.public]               1.0  0.000492
# 10989  [ncbi.public, s3.us-east-1, gs.us-east1]               1.0  0.000401
# 10990  [gs.us-east1, ncbi.public, s3.us-east-1]               1.0  0.000312
# 10991  [gs.us-east1, ncbi.public, s3.us-east-1]               1.0  0.000167
#
# [10992 rows x 36 columns]

# %%
attr = sra['biosample'].apply(biosample.get_biosample)
attr.index = sra['biosample']
attr = attr.apply(biosample.from_biosample)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/response.py:697, in HTTPResponse._update_chunk_length(self)
#     696 try:
# --> 697     self.chunk_left = int(line, 16)
#     698 except ValueError:
#     699     # Invalid chunked protocol response, abort.
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/response.py:438, in HTTPResponse._error_catcher(self)
#     437 try:
# --> 438     yield
#     440 except SocketTimeout:
#     441     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     442     # there is yet no clean way to get at it from this context.
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:764, in HTTPResponse.read_chunked(self, amt, decode_content)
#     763 while True:
# --> 764     self._update_chunk_length()
#     765     if self.chunk_left == 0:
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:701, in HTTPResponse._update_chunk_length(self)
#     700 self.close()
# --> 701 raise InvalidChunkLength(self, line)
#
# InvalidChunkLength: InvalidChunkLength(got length b'', 0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/requests/models.py:753, in Response.iter_content.<locals>.generate()
#     752 try:
# --> 753     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754         yield chunk
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:572, in HTTPResponse.stream(self, amt, decode_content)
#     571 if self.chunked and self.supports_chunked_reads():
# --> 572     for line in self.read_chunked(amt, decode_content=decode_content):
#     573         yield line
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:752, in HTTPResponse.read_chunked(self, amt, decode_content)
#     747     raise BodyNotHttplibCompatible(
#     748         "Body should be http.client.HTTPResponse like. "
#     749         "It should have have an fp attribute which returns raw chunks."
#     750     )
# --> 752 with self._error_catcher():
#     753     # Don't bother reading the body of a HEAD request.
#     754     if self._original_response and is_response_to_head(self._original_response):
#
# File /usr/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:455, in HTTPResponse._error_catcher(self)
#     453 except (HTTPException, SocketError) as e:
#     454     # This includes IncompleteRead.
# --> 455     raise ProtocolError("Connection broken: %r" % e, e)
#     457 # If no exception is thrown, we should avoid cleaning up
#     458 # unnecessarily.
#
# ProtocolError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 attr = sra['biosample'].apply(biosample.get_biosample)
#       2 attr.index = sra['biosample']
#       3 attr = attr.apply(biosample.from_biosample)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/Code/sra-genomics/metadata/biosample.py:5, in get_biosample(biosamp_id)
#       3 def get_biosample(biosamp_id):
#       4     api_url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=biosample&id={biosamp_id}&rettype=full&retmode=text"
# ----> 5     res = requests.get(api_url)
#       6     return res.text
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:699, in Session.send(self, request, **kwargs)
#     696         pass
#     698 if not stream:
# --> 699     r.content
#     701 return r
#
# File /usr/lib/python3/dist-packages/requests/models.py:831, in Response.content(self)
#     829         self._content = None
#     830     else:
# --> 831         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     833 self._content_consumed = True
#     834 # don't need to release the connection; that's been handled by urllib3
#     835 # since we exhausted the data.
#
# File /usr/lib/python3/dist-packages/requests/models.py:756, in Response.iter_content.<locals>.generate()
#     754         yield chunk
#     755 except ProtocolError as e:
# --> 756     raise ChunkedEncodingError(e)
#     757 except DecodeError as e:
#     758     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))

# %%
biosample = pd.DataFrame.from_records(attr, index=sra['biosample'])
biosample

# %%
attributes = pd.DataFrame.from_records(biosample['Attributes'].dropna(), index=biosample['Attributes'].dropna().index)
identifiers = pd.DataFrame.from_records(biosample['Identifiers'].dropna(), index=biosample['Identifiers'].dropna().index)

# %%
biosample = pd.DataFrame(biosample['title']).join([attributes, identifiers])
biosample

# %%
biosample.to_csv('biosample.csv')
