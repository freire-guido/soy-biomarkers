# %%
import pandas as pd
import bioproject

# %%
joined = pd.read_csv('../data/joined.csv')
bioprojects = pd.DataFrame(index=joined['bioproject'].unique())
bioprojects.index.name = 'bioproject'
bioprojects
# Out:
# /tmp/ipykernel_14589/3379004096.py:1: DtypeWarning: Columns (28,29,30,49,51,54,55,56,57,59,60,61,62,63,65,66,67,71,72,73,74,75,76,78,79,80,81,82,83,84,85,87,88,89,91,92,93,94,96,98,99,100,102,103,104,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,135,136,137,138,139,140,141,142,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,162,163,164,166,167,168,169,170,171,172,173,174,175,176,177,179,180,182,183,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269) have mixed types. Specify dtype option on import or set low_memory=False.
#   joined = pd.read_csv('../data/joined.csv')
# Empty DataFrame
# Columns: []
# ...

# %%
pd.read_csv('venancio.csv')
# Out:
#       bioproject stress   n      part  \
# 0    PRJNA218821   acid   1   root: 1
# 1    PRJNA218823   acid   1   root: 1
# 2    PRJNA218825   acid   1   root: 1
# 3    PRJNA373639   acid   1   root: 1
# 4    PRJNA373640   acid   1   root: 1
# ..           ...    ...  ..       ...
# 394  PRJNA811603    NaN  12  root: 12
# 395  PRJNA819554    NaN   6   seed: 6
# 396  PRJNA823397    NaN  12  leaf: 12
# 397  PRJNA827666    NaN   6   root: 6
# 398  PRJNA832118    NaN  24  leaf: 24
#
#                                                  title  \
# 0    Glycine max strain:Williams 82 Transcriptome o...
# 1    Glycine max strain:Williams 82 Transcriptome o...
# 2    Glycine max strain:Williams 82 Transcriptome o...
# 3    Gene expression profiling of Glycine max Willi...
# 4    Gene expression profiling of Glycine max Willi...
# ..                                                 ...
# 394  Identification of Candidate Genes for a Major ...
# ...

# %%
bioprojects = bioprojects.join(venancio)

# %%
xml = bioprojects.apply(bioproject.get_bioproject)
