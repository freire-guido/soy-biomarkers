# %%
import pandas as pd
import bioproject

# %%
sra = pd.read_csv('sra.csv')
bioprojects = pd.DataFrame({'bioproject': sra['bioproject'].unique()})
bioprojects
# Out:
# /tmp/ipykernel_141903/4099618474.py:1: DtypeWarning: Columns (60,69,72,78,95,96,97,103,104,105,109,112,116,121,122,132,133,138,139,141,145,146,147,161,166,167,169,170,171,173,174,176,177,179,180,186,187,188,189,190,191,192,193,194,195,196,197,199,200,201,202,203,204,205,207,212,213,218,219,220,222,224,225,226,227,228,229,230,231,232,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266) have mixed types. Specify dtype option on import or set low_memory=False.
#   sra = pd.read_csv('sra.csv')
#       bioproject
# 0     PRJDB10183
# 1    PRJNA881271
# 2    PRJNA478334
# 3    PRJNA464061
# 4    PRJNA999924
# ..           ...
# 785  PRJNA409457
# 786  PRJNA372529
# 787  PRJNA373608
# 788  PRJNA409521
# 789  PRJNA410694
#
# [790 rows x 1 columns]

# %%
try:
    attr = pd.read_csv('bioproject_attributes.csv')
except:
    attr = bioprojects['bioproject'].apply(bioproject.get_bioproject)
    attr.index = bioprojects['bioproject']
    attr = attr.apply(bioproject.from_bioproject)
    attr.to_csv('bioproject_attributes.csv')
attr
# Out:
# bioproject
# PRJDB10183     {'name': 'Glycine max', 'title': 'RNA sequenci...
# PRJNA881271    {'name': 'Inner Mongolia Academy of Agricultur...
# PRJNA478334                                                   {}
# PRJNA464061    {'name': 'Epigenomics of Glycine max', 'title'...
# PRJNA999924    {'name': 'soybean', 'title': 'Study on chillin...
#                                      ...
# PRJNA409457    {'name': 'Glycine max cultivar:Williams 82', '...
# PRJNA372529    {'name': 'Glycine max cultivar:williams82', 't...
# PRJNA373608    {'name': 'Glycine max cultivar:Williams 82', '...
# PRJNA409521    {'name': 'Glycine max cultivar:Williams 82', '...
# PRJNA410694    {'name': 'Glycine max cultivar:Williams 82', '...
# Name: bioproject, Length: 790, dtype: object

# %%
bioprojects = pd.DataFrame.from_records(attr, index=attr.index)
bioprojects
# Out:
# /tmp/ipykernel_141903/510357021.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bioprojects = pd.DataFrame.from_records(attr, index=bioprojects.index)
#                                                   name  \
# 0                                          Glycine max
# 1    Inner Mongolia Academy of Agricultural &amp; A...
# 2                                                  NaN
# 3                           Epigenomics of Glycine max
# 4                                              soybean
# ..                                                 ...
# 785                   Glycine max cultivar:Williams 82
# 786                    Glycine max cultivar:williams82
# 787                   Glycine max cultivar:Williams 82
# 788                   Glycine max cultivar:Williams 82
# ...

# %%
bioprojects['abstract'] = bioprojects['doi'].apply(bioproject.get_abstract)
bioprojects
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bioprojects['abstract'] = bioprojects['doi'].apply(bioproject.get_abstract)
#       2 bioprojects
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# ...

# %%
bioprojects.to_csv('bioproject.csv')
