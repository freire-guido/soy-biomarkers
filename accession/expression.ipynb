# %%
import pandas as pd

# %%
projects = pd.read_json('venancio.json')
projects.columns = ['BioProject', 'N', 'Part', 'Title', 'Abstract', 'DOI', 'PMID']
projects
# Out:
#       BioProject   N                       Part  \
# 0    PRJNA360609   8                seedling: 8
# 1    PRJNA369113  36                   leaf: 36
# 2    PRJNA369414  21  embryo: 15 | cotyledon: 6
# 3    PRJNA369483   6                    seed: 6
# 4    PRJNA372408   1                   shoot: 1
# ..           ...  ..                        ...
# 489  PRJNA827520   6                    leaf: 6
# 490  PRJNA827666   6                    root: 6
# 491  PRJNA832118  24                   leaf: 24
# 492  PRJNA833532  12                   root: 12
# 493  PRJNA834849   6                    leaf: 6
#
#                                                  Title  \
# 0    Transgenic and conventional cultivar compariso...
# 1    Circadian transcriptome of soybean unifoliolat...
# 2    Genome-Wide Reinforcement of DNA Methylation O...
# 3    Characterizing seed weight related genes throu...
# 4    Gene expression analysis of Glycine max willia...
# ...

# %%
estreses = ['drought', 'yield', 'acid', 'inoculation', 'fungal', 'pathogen']
for estres in estreses:
    print(estres + ': ' + str(projects['Abstract'].str.contains(estres).sum()))
# Out:
# drought: 22
# yield: 26
# acid: 12
# inoculation: 10
# fungal: 4
# pathogen: 15

# %%
pd.read_csv('GA.v2.Glycine.max...Samples.2024.08.03_18.26.29.882803.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_csv('GA.v2.Glycine.max...Samples.2024.08.03_18.26.29.882803.csv')
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
