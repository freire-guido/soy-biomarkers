# %%
import pandas as pd

# %%
metadata = pd.read_csv('../data/joined.csv', index_col=0)
metadata
# Out:
# /tmp/ipykernel_33347/3173754459.py:1: DtypeWarning: Columns (28,29,30,49,51,54,55,56,57,59,60,61,62,63,65,66,67,71,72,73,74,75,76,78,79,80,81,82,83,84,85,87,88,89,91,92,93,94,96,98,99,100,102,103,104,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,135,136,137,138,139,140,141,142,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,162,163,164,166,167,168,169,170,171,172,173,174,175,176,177,179,180,182,183,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv('../data/joined.csv', index_col=0)
#                       acc assay_type              center_name consent  \
# biosample
# SAMD00025071    DRR029571    RNA-Seq                    NUGSS  public
# SAMD00025072    DRR029572    RNA-Seq                    NUGSS  public
# SAMD00025073    DRR029573    RNA-Seq                    NUGSS  public
# SAMD00025074    DRR029574    RNA-Seq                    NUGSS  public
# SAMD00025075    DRR029575    RNA-Seq                    NUGSS  public
# ...                   ...        ...                      ...     ...
# SAMN41829221  SRR29409034    RNA-Seq  KANSAS STATE UNIVERSITY  public
# SAMN41829222  SRR29409033    RNA-Seq  KANSAS STATE UNIVERSITY  public
# SAMN41829223  SRR29409032    RNA-Seq  KANSAS STATE UNIVERSITY  public
# SAMN41829224  SRR29409031    RNA-Seq  KANSAS STATE UNIVERSITY  public
# SAMN41829225  SRR29409030    RNA-Seq  KANSAS STATE UNIVERSITY  public
#
#                experiment sample_name                    instrument  \
# biosample
# SAMD00025071    DRX026629   DRS020767  Illumina Genome Analyzer IIx
# SAMD00025072    DRX026630   DRS020768  Illumina Genome Analyzer IIx
# SAMD00025073    DRX026631   DRS020769  Illumina Genome Analyzer IIx
# SAMD00025074    DRX026632   DRS020770  Illumina Genome Analyzer IIx
# SAMD00025075    DRX026633   DRS020771  Illumina Genome Analyzer IIx
# ...                   ...         ...                           ...
# SAMN41829221  SRX24922515  Soybean308                   NextSeq 500
# SAMN41829222  SRX24922516  Soybean309                   NextSeq 500
# SAMN41829223  SRX24922517  Soybean310                   NextSeq 500
# SAMN41829224  SRX24922518  Soybean311                   NextSeq 500
# SAMN41829225  SRX24922519  Soybean312                   NextSeq 500
#
#              librarylayout libraryselection   librarysource  ... er_gfp_sam  \
# biosample                                                    ...
# SAMD00025071        SINGLE           RANDOM  TRANSCRIPTOMIC  ...        NaN
# SAMD00025072        SINGLE           RANDOM  TRANSCRIPTOMIC  ...        NaN
# SAMD00025073        SINGLE           RANDOM  TRANSCRIPTOMIC  ...        NaN
# SAMD00025074        SINGLE           RANDOM  TRANSCRIPTOMIC  ...        NaN
# SAMD00025075        SINGLE           RANDOM  TRANSCRIPTOMIC  ...        NaN
# ...                    ...              ...             ...  ...        ...
# SAMN41829221        SINGLE             cDNA  TRANSCRIPTOMIC  ...        NaN
# SAMN41829222        SINGLE             cDNA  TRANSCRIPTOMIC  ...        NaN
# SAMN41829223        SINGLE             cDNA  TRANSCRIPTOMIC  ...        NaN
# SAMN41829224        SINGLE             cDNA  TRANSCRIPTOMIC  ...        NaN
# SAMN41829225        SINGLE             cDNA  TRANSCRIPTOMIC  ...        NaN
#
#              subsrc_note_sam_s_dpl392 authors_sam env_biome_sam  \
# biosample
# SAMD00025071                      NaN         NaN           NaN
# SAMD00025072                      NaN         NaN           NaN
# SAMD00025073                      NaN         NaN           NaN
# SAMD00025074                      NaN         NaN           NaN
# SAMD00025075                      NaN         NaN           NaN
# ...                               ...         ...           ...
# SAMN41829221                      NaN         NaN           NaN
# SAMN41829222                      NaN         NaN           NaN
# SAMN41829223                      NaN         NaN           NaN
# SAMN41829224                      NaN         NaN           NaN
# SAMN41829225                      NaN         NaN           NaN
#
#                                                      title  \
# biosample
# SAMD00025071  Error: uid 25071 cannot get document summary
# SAMD00025072  Error: uid 25072 cannot get document summary
# SAMD00025073  Error: uid 25073 cannot get document summary
# SAMD00025074  Error: uid 25074 cannot get document summary
# SAMD00025075  Error: uid 25075 cannot get document summary
# ...                                                    ...
# SAMN41829221                 Plant sample from Glycine max
# SAMN41829222                 Plant sample from Glycine max
# SAMN41829223                 Plant sample from Glycine max
# SAMN41829224                 Plant sample from Glycine max
# SAMN41829225                 Plant sample from Glycine max
#
#                                                     Identifiers     Organism  \
# biosample
# SAMD00025071                                                NaN          NaN
# SAMD00025072                                                NaN          NaN
# SAMD00025073                                                NaN          NaN
# SAMD00025074                                                NaN          NaN
# SAMD00025075                                                NaN          NaN
# ...                                                         ...          ...
# SAMN41829221  {'BioSample': 'SAMN41829221', 'Sample name': '...  Glycine max
# SAMN41829222  {'BioSample': 'SAMN41829222', 'Sample name': '...  Glycine max
# SAMN41829223  {'BioSample': 'SAMN41829223', 'Sample name': '...  Glycine max
# SAMN41829224  {'BioSample': 'SAMN41829224', 'Sample name': '...  Glycine max
# SAMN41829225  {'BioSample': 'SAMN41829225', 'Sample name': '...  Glycine max
#
#                                               Attributes     Accession  \
# biosample
# SAMD00025071                                         NaN           NaN
# SAMD00025072                                         NaN           NaN
# SAMD00025073                                         NaN           NaN
# SAMD00025074                                         NaN           NaN
# SAMD00025075                                         NaN           NaN
# ...                                                  ...           ...
# SAMN41829221   {'cultivar': 'Pharaoh', 'tissue': 'Stem'}  SAMN41829221
# SAMN41829222   {'cultivar': 'Pharaoh', 'tissue': 'Stem'}  SAMN41829222
# SAMN41829223   {'cultivar': 'Pharaoh', 'tissue': 'Stem'}  SAMN41829223
# SAMN41829224  {'cultivar': 'Dt974290', 'tissue': 'Stem'}  SAMN41829224
# SAMN41829225  {'cultivar': 'Dt974290', 'tissue': 'Stem'}  SAMN41829225
#
#                       ID
# biosample
# SAMD00025071         NaN
# SAMD00025072         NaN
# SAMD00025073         NaN
# SAMD00025074         NaN
# SAMD00025075         NaN
# ...                  ...
# SAMN41829221  41829221.0
# SAMN41829222  41829222.0
# SAMN41829223  41829223.0
# SAMN41829224  41829224.0
# SAMN41829225  41829225.0
#
# [10992 rows x 275 columns]

# %%
def matching_cols(row, pat):
    return row[row.astype(str).str.contains(pat, regex=False, case=False).fillna(False)].to_dict()

# %% [markdown]
# Junto palabras clave en kws. Guardo ```{columna: valor}``` en ```estreses``` si la columna contiene la palabra clave en su valor.

# %%
kws = ['control', 'ctrl', 'stress', 'drought', 'bacteria', 'inoculated', 'flood', 'deficit', 'infest', 'pathogen', 'acid', 'fung', 'sporus']
estreses = pd.DataFrame(index = metadata.index)

for kw in kws:
    estreses[kw] = metadata.apply(lambda r: matching_cols(r, kw), axis=1)

# %%
indicadores = estreses.map(lambda v: v != {})
indicadores
# Out:
#               control   ctrl  stress  drought  bacteria  inoculated  flood  \
# biosample
# SAMD00025071    False  False   False    False     False       False  False
# SAMD00025072    False  False   False    False     False       False  False
# SAMD00025073    False  False   False    False     False       False  False
# SAMD00025074    False  False   False    False     False       False  False
# SAMD00025075    False  False   False    False     False       False  False
# ...               ...    ...     ...      ...       ...         ...    ...
# SAMN41829221    False  False   False    False     False       False  False
# SAMN41829222    False  False   False    False     False       False  False
# SAMN41829223    False  False   False    False     False       False  False
# SAMN41829224    False  False   False    False     False       False  False
# SAMN41829225    False  False   False    False     False       False  False
#
#               deficit  infest  pathogen   acid   fung  sporus
# biosample
# SAMD00025071    False   False     False  False  False   False
# SAMD00025072    False   False     False  False  False   False
# SAMD00025073    False   False     False  False  False   False
# SAMD00025074    False   False     False  False  False   False
# SAMD00025075    False   False     False  False  False   False
# ...               ...     ...       ...    ...    ...     ...
# SAMN41829221    False   False     False  False  False   False
# SAMN41829222    False   False     False  False  False   False
# SAMN41829223    False   False     False  False  False   False
# SAMN41829224    False   False     False  False  False   False
# SAMN41829225    False   False     False  False  False   False
#
# [10992 rows x 13 columns]

# %%
indicadores.sum(axis=0)
# Out:
# control       441
# ctrl           13
# stress        485
# drought        84
# bacteria        0
# inoculated    339
# flood           0
# deficit       135
# infest        141
# pathogen        3
# acid           79
# fung           12
# sporus          9
# dtype: int64

# %%
indicadores.sum(axis=1)
# Out:
# biosample
# SAMD00025071    0
# SAMD00025072    0
# SAMD00025073    0
# SAMD00025074    0
# SAMD00025075    0
#                ..
# SAMN41829221    0
# SAMN41829222    0
# SAMN41829223    0
# SAMN41829224    0
# SAMN41829225    0
# Length: 10992, dtype: int64

# %%
estreses = estreses[indicadores.sum(axis=1) > 0]
indicadores = indicadores.loc[estreses.index]
estreses.to_csv('estreses.csv')

# %% [markdown]
# # Condición
# ## Estres vs. control

# %%
def cols_true(row):
# Devuelve lista de columnas verdaderas para row
    return row[row].index.to_list()

# %% [markdown]
# ## Control

# %%
condicion = pd.DataFrame(index = estreses.index)
condicion.loc[indicadores['control'] | indicadores['ctrl'], 'condicion'] = 'control'

# %%
bioprojects = pd.read_csv('../metadata/venancio.csv', index_col=0)
bioprojects[bioprojects['stress'] == 'control']
# Out:
#               stress    n               part  \
# bioproject
# PRJNA250761  control    1         unknown: 1
# PRJNA251047  control    1         unknown: 1
# PRJNA271453  control    3  leaf: 2 | root: 1
# PRJNA271506  control    2          flower: 2
# PRJNA339653  control    4            leaf: 4
# ...              ...  ...                ...
# PRJNA668549  control    8            leaf: 8
# PRJNA758180  control    1       hypocotyl: 1
# PRJNA801060  control   18           seed: 18
# PRJNA389558  control  102          leaf: 102
# PRJNA692674  control    6            leaf: 6
#
#                                                          title  \
# bioproject
# PRJNA250761  Glycine max strain:williams82 Transcriptome or...
# PRJNA251047  Glycine max strain:Williams 82 Transcriptome o...
# PRJNA271453       Glycine max Transcriptome or Gene expression
# PRJNA271506       Glycine max Transcriptome or Gene expression
# PRJNA339653                     Glycine max Raw sequence reads
# ...                                                        ...
# PRJNA668549                Soybean Transcriptome (clean reads)
# PRJNA758180                     Glycine max Raw sequence reads
# PRJNA801060                     Glycine max Raw sequence reads
# PRJNA389558           Transcriptomes of 102 soybean accessions
# PRJNA692674  RNAseq analysis of pooled soybean leaf samples...
#
#                                                       abstract  doi pmid
# bioproject
# PRJNA250761                      JGI Flagship Plant Gene Atlas  NaN  NaN
# PRJNA251047                      JGI Flagship Plant Gene Atlas  NaN  NaN
# PRJNA271453        Transcriptome sequencing of Glycine max C08  NaN  NaN
# PRJNA271506           soybean Transcriptome or Gene expression  NaN  NaN
# PRJNA339653                      RNA-seq of soybean accessions  NaN  NaN
# ...                                                        ...  ...  ...
# PRJNA668549  Discover SMV-resistance genes/networks in soyb...  NaN  NaN
# PRJNA758180                          Glycine max RNA-seq reads  NaN  NaN
# PRJNA801060                    normal RNA-Seq of soybean seeds  NaN  NaN
# PRJNA389558  A comparison of RNA expression profiles across...  NaN  NaN
# PRJNA692674  Leaf samples were collected from soybean produ...  NaN  NaN
#
# [154 rows x 7 columns]

# %%
sample_stress_project = metadata.reset_index().set_index('bioproject').join(bioprojects, rsuffix='_bioprj').set_index('biosample')['stress']
condicion.loc[sample_stress_project == 'control', 'condicion'] = 'control'

# %%
control = condicion['condicion'] == 'control'

# %% [markdown]
# ## Estrés

# %%
condicion.loc[~control, 'condicion'] = indicadores[~control].apply(cols_true, axis = 1)
condicion
# Out:
#               condicion
# biosample
# SAMD00133783    control
# SAMD00133784  [drought]
# SAMD00133785    control
# SAMD00133786  [drought]
# SAMD00133787    control
# ...                 ...
# SAMN40876398    control
# SAMN40876399    control
# SAMN40876400   [stress]
# SAMN40876401   [stress]
# SAMN40876402   [stress]
#
# [1574 rows x 1 columns]

# %%
multi = ~control & (condicion.loc[~control, 'condicion'].map(len) > 1)
condicion[multi]
# Out:
#                            condicion
# biosample
# SAMD00222779  [inoculated, pathogen]
# SAMN03755595       [stress, deficit]
# SAMN03755596       [stress, deficit]
# SAMN03755597       [stress, deficit]
# SAMN03755601       [stress, deficit]
# ...                              ...
# SAMN38032658       [stress, drought]
# SAMN38032659       [stress, drought]
# SAMN38032660       [stress, drought]
# SAMN38032661       [stress, drought]
# SAMN38032662       [stress, drought]
#
# [100 rows x 1 columns]

# %% [markdown]
# Muchas muestras tienen stress además del estrés específico. Me quedo con este último.

# %%
condicion.loc[multi, 'condicion'] = condicion.loc[multi, 'condicion'].apply(lambda r: [s for s in r if s != 'stress'])
condicion[multi]
# Out:
#                            condicion
# biosample
# SAMD00222779  [inoculated, pathogen]
# SAMN03755595               [deficit]
# SAMN03755596               [deficit]
# SAMN03755597               [deficit]
# SAMN03755601               [deficit]
# ...                              ...
# SAMN38032658               [drought]
# SAMN38032659               [drought]
# SAMN38032660               [drought]
# SAMN38032661               [drought]
# SAMN38032662               [drought]
#
# [100 rows x 1 columns]

# %% [markdown]
# Repito a ver cuales quedaron con varios estreses

# %%
multi = ~control & (condicion.loc[~control, 'condicion'].map(len) > 1)
condicion[multi]
# Out:
#                            condicion
# biosample
# SAMD00222779  [inoculated, pathogen]
# SAMN08469975  [inoculated, pathogen]
# SAMN08469977  [inoculated, pathogen]
# SAMN09295122      [inoculated, fung]
# SAMN09295123      [inoculated, fung]
# SAMN09295124      [inoculated, fung]
# SAMN09295128      [inoculated, fung]
# SAMN09295129      [inoculated, fung]
# SAMN09295130      [inoculated, fung]
# SAMN36630190         [deficit, acid]
# SAMN36630191         [deficit, acid]
# SAMN36630192         [deficit, acid]
# SAMN36630193         [deficit, acid]
# SAMN36630194         [deficit, acid]
# SAMN36630195         [deficit, acid]
# SAMN36630196         [deficit, acid]
# SAMN36630197         [deficit, acid]
# SAMN36630198         [deficit, acid]
# SAMN36630205         [deficit, acid]
# SAMN36630206         [deficit, acid]
# SAMN36630207         [deficit, acid]
# SAMN36630214         [deficit, acid]
# SAMN36630215         [deficit, acid]
# SAMN36630216         [deficit, acid]
# SAMN36630244         [deficit, acid]
# SAMN36630245         [deficit, acid]
# SAMN36630246         [deficit, acid]
# SAMN36630247         [deficit, acid]
# SAMN36630248         [deficit, acid]
# SAMN36630249         [deficit, acid]
# SAMN36630250         [deficit, acid]
# SAMN36630251         [deficit, acid]
# SAMN36630252         [deficit, acid]
# SAMN36630259         [deficit, acid]
# SAMN36630260         [deficit, acid]
# SAMN36630261         [deficit, acid]
# SAMN36630268         [deficit, acid]
# SAMN36630269         [deficit, acid]
# SAMN36630270         [deficit, acid]

# %%
condicion.loc[multi, 'condicion'] = condicion.loc[multi, 'condicion'].apply(lambda r: [s for s in r if s != 'deficit' and s != 'inoculated'])
condicion[multi]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 condicion.loc[multi, 'condicion'] = condicion.loc[multi, 'condicion'].apply(lambda r: [s for s in r if s != 'deficit' and s != 'inoculated'], axis=1)
#       2 condicion[multi]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1496, in SeriesApply.apply_standard.<locals>.curried(x)
#    1495 def curried(x):
# -> 1496     return func(x, *self.args, **self.kwargs)
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'

# %% [markdown]
# Ahora los transformo a ```str```

# %%
isinstance(condicion.iloc[1,0], list)
# Out:
# True

# %%
condicion.to_csv('condicion.csv')
